# %% [markdown]
# # Interactive maps

# %% [markdown]
# Interactive maps allow users to engage with the map content through, for example, zooming, panning, clicking, and searching. There are various tools available for creating interactive maps in Python. In this chapter, we will first see how we can create interactive maps directly from `geopandas`, and proceed to learning more about customizing the interactive maps in Python using the [`folium` library](https://python-visualization.github.io/folium/) [^folium]. Folium makes it easy to visualize geographic data by integrating with [`Leaflet.js`](http://leafletjs.com/) [^leaflet], a powerful JavaScript library for interactive mapping. JavaScript (JS) is a programming language commonly used to add dynamic and interactive elements to webpages, and Leaflet is one of the many JavaScript libraries designed specifically for rendering interactive maps. `Folium` makes these tools accessible for Python users who want to integrate dynamic map content in their data analysis workflows. By using `folium`, we can leverage the capabilities of `Leaflet.js` without needing to write JavaScript code.
#
# ## Interactive data exploration using `geopandas`
#
# In previous chapters, we have already created simple examples of interactive maps via `geopandas` to explore our data interactively on top of a basemap. `Geopandas.GeoDataFrame.explore()` uses `folium`/`leaflet.js` to create the map and we can adjust the map object parameters directly from `geopandas`.
#
# Let's create an interactive map via `geopandas` using point data. Our sample dataset represent city bike stations in Espoo and Helsinki, Finland based on open data from [Helsinki Region Transport’s (HSL)](https://www.avoindata.fi/data/en_GB/dataset/hsl-n-kaupunkipyoraasemat) [^hsl_citybikedata].

# %%
import geopandas as gpd

points_fp = "./../data/hrtopendata_citybikes_helsinki_espoo_2025.gpkg"
points = gpd.read_file(points_fp, columns=["ID", "Name", "Osoite", "Kapasiteet"])

points = points.rename(columns={"Osoite": "Address", "Kapasiteet": "Capacity"})
points.explore(marker_type="marker")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be7c8c4a726e7d259e3c5fac88e4e556 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be7c8c4a726e7d259e3c5fac88e4e556&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be7c8c4a726e7d259e3c5fac88e4e556 = L.map(
#                 &quot;map_be7c8c4a726e7d259e3c5fac88e4e556&quot;,
#                 {
#                     center: [60.21433853734813, 24.9403566745883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_be7c8c4a726e7d259e3c5fac88e4e556);
#
#
#
#
#
#             var tile_layer_c97b0cc38b4ec1e69cf45daf697f4400 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c97b0cc38b4ec1e69cf45daf697f4400.addTo(map_be7c8c4a726e7d259e3c5fac88e4e556);
#
#
#             map_be7c8c4a726e7d259e3c5fac88e4e556.fitBounds(
#                 [[60.14792099956579, 24.721367000363124], [60.280756075130455, 25.159346348813475]],
#                 {}
#             );
#
#
#         function geo_json_71ccf9eff203fc0a9079ac178754597e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_71ccf9eff203fc0a9079ac178754597e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_71ccf9eff203fc0a9079ac178754597e_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_71ccf9eff203fc0a9079ac178754597e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_71ccf9eff203fc0a9079ac178754597e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_71ccf9eff203fc0a9079ac178754597e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_71ccf9eff203fc0a9079ac178754597e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_71ccf9eff203fc0a9079ac178754597e = L.geoJson(null, {
#                 onEachFeature: geo_json_71ccf9eff203fc0a9079ac178754597e_onEachFeature,
#
#                 style: geo_json_71ccf9eff203fc0a9079ac178754597e_styler,
#                 pointToLayer: geo_json_71ccf9eff203fc0a9079ac178754597e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_71ccf9eff203fc0a9079ac178754597e_add (data) {
#             geo_json_71ccf9eff203fc0a9079ac178754597e
#                 .addData(data);
#         }
#             geo_json_71ccf9eff203fc0a9079ac178754597e_add({&quot;bbox&quot;: [24.721367000363124, 60.14792099956579, 25.159346348813475, 60.280756075130455], &quot;features&quot;: [{&quot;bbox&quot;: [24.84031900081687, 60.16582000019192, 24.84031900081687, 60.16582000019192], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.84031900081687, 60.16582000019192], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;Hanasaarenranta 1&quot;, &quot;Capacity&quot;: 10, &quot;ID&quot;: &quot;501&quot;, &quot;Name&quot;: &quot;Hanasaari&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [24.827466999929044, 60.1715239996662, 24.827466999929044, 60.1715239996662], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.827466999929044, 60.1715239996662], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;Keilalahdentie 2&quot;, &quot;Capacity&quot;: 28, &quot;ID&quot;: &quot;503&quot;, &quot;Name&quot;: &quot;Keilalahti&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [24.805758000284836, 60.16826599993541, 24.805758000284836, 60.16826599993541], &qu

# %% [markdown]
# % This cell is only needed to produce a figure for display in the hard copy of the book.
# \adjustimage{max size={0.9\linewidth}{0.9\paperheight}, caption={\emph{\textbf{Figure 8.XX}. Interactive map with point data created using geopandas.GeoDataFrame.explore().}}, center, nofloat}{../img/figure_8-xx.png}
# { \hspace*{\fill} \\}

# %% [markdown]
# _**Figure 8.XX**. Interactive map with point data created using geopandas.GeoDataFrame.explore()._

# %% [markdown]
# This interactive map allows us to zoom in and out to explore the locations of our point data. By default, we can hover over the point features to view attribute information.

# %% [markdown]
# ### Changing the basemap
#
# The bacground map can be controlled  via the `tiles` argument. Folium includes built-in background map tiles (such as `"OpenStreetmap"` and `"CartoDB Positron"`) and allows the use of custom URLs to define the bacground map. All tilesets available in the [`xyzservices` library](https://xyzservices.readthedocs.io/en/stable/) [^xyzservices] can be used via `folium`. You can preview available basemaps in the [Leaflet providers preview](https://leaflet-extras.github.io/leaflet-providers/preview/) [^leaflet_providers].

# %%
points.explore(marker_type="marker", tiles="CartoDB Positron")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f629d2cc0e0eeed407a0d2c899ce7f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f629d2cc0e0eeed407a0d2c899ce7f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f629d2cc0e0eeed407a0d2c899ce7f5 = L.map(
#                 &quot;map_7f629d2cc0e0eeed407a0d2c899ce7f5&quot;,
#                 {
#                     center: [60.21433853734813, 24.9403566745883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_7f629d2cc0e0eeed407a0d2c899ce7f5);
#
#
#
#
#
#             var tile_layer_1aa40681d3ccf0eadd09ccd890d95140 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1aa40681d3ccf0eadd09ccd890d95140.addTo(map_7f629d2cc0e0eeed407a0d2c899ce7f5);
#
#
#             map_7f629d2cc0e0eeed407a0d2c899ce7f5.fitBounds(
#                 [[60.14792099956579, 24.721367000363124], [60.280756075130455, 25.159346348813475]],
#                 {}
#             );
#
#
#         function geo_json_32c56975b22274aa9d7e3b079be154a9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_32c56975b22274aa9d7e3b079be154a9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_32c56975b22274aa9d7e3b079be154a9_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_32c56975b22274aa9d7e3b079be154a9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_32c56975b22274aa9d7e3b079be154a9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_32c56975b22274aa9d7e3b079be154a9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_32c56975b22274aa9d7e3b079be154a9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_32c56975b22274aa9d7e3b079be154a9 = L.geoJson(null, {
#                 onEachFeature: geo_json_32c56975b22274aa9d7e3b079be154a9_onEachFeature,
#
#                 style: geo_json_32c56975b22274aa9d7e3b079be154a9_styler,
#                 pointToLayer: geo_json_32c56975b22274aa9d7e3b079be154a9_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_32c56975b22274aa9d7e3b079be154a9_add (data) {
#             geo_json_32c56975b22274aa9d7e3b079be154a9
#                 .addData(data);
#         }
#             geo_json_32c56975b22274aa9d7e3b079be154a9_add({&quot;bbox&quot;: [24.721367000363124, 60.14792099956579, 25.159346348813475, 60.280756075130455], &quot;features&quot;: [{&quot;bbox&quot;: [24.84031900081687, 60.16582000019192, 24.84031900081687, 60.16582000019192], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.84031900081687, 60.16582000019192], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;Hanasaarenranta 1&quot;, &quot;Capacity&quot;: 10, &quot;ID&quot;: &quot;501&quot;, &quot;Name&quot;: &quot;Hanasaari&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [24.827466999929044, 60.1715239996662, 24.827466999929044, 60.1715239996662], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.827466999929044, 60.1715239996662], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;Keilalahdentie 2&quot;, &quot;Capacity&quot;: 28, &quot;ID&quot;: &quot;503&quot;, &quot;Name&quot;: &quot;Keilalahti&quot;}, &quot;type&quot;: &quot;Feature&q

# %% [markdown]
# Note that `folium` automatically adds attribution to the default map-tiles in the bottom-right corner of the map. We can also pass a custom tileset using an URL in the format `https://{s}.yourtiles.com/{z}/{x}/{y}.png`. When using an URL, we also need to add the map tile attribution separately.

# %%
points.explore(
    marker_type="marker",
    tiles="https://{s}.tile-cyclosm.openstreetmap.fr/cyclosm/{z}/{x}/{y}.png",
    attr='<a href="https://github.com/cyclosm/cyclosm-cartocss-style/releases" title="CyclOSM - Open Bicycle render">CyclOSM</a> | Map data: &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eafce548b8a5562992b0736dd2d7d18c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eafce548b8a5562992b0736dd2d7d18c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eafce548b8a5562992b0736dd2d7d18c = L.map(
#                 &quot;map_eafce548b8a5562992b0736dd2d7d18c&quot;,
#                 {
#                     center: [60.21433853734813, 24.9403566745883],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_eafce548b8a5562992b0736dd2d7d18c);
#
#
#
#
#
#             var tile_layer_32f2b16524776beb772a8017d8319fe5 = L.tileLayer(
#                 &quot;https://{s}.tile-cyclosm.openstreetmap.fr/cyclosm/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u003ca href=\&quot;https://github.com/cyclosm/cyclosm-cartocss-style/releases\&quot; title=\&quot;CyclOSM - Open Bicycle render\&quot;\u003eCyclOSM\u003c/a\u003e | Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32f2b16524776beb772a8017d8319fe5.addTo(map_eafce548b8a5562992b0736dd2d7d18c);
#
#
#             map_eafce548b8a5562992b0736dd2d7d18c.fitBounds(
#                 [[60.14792099956579, 24.721367000363124], [60.280756075130455, 25.159346348813475]],
#                 {}
#             );
#
#
#         function geo_json_b77015d96164d293a21eb0f85569b29a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b77015d96164d293a21eb0f85569b29a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b77015d96164d293a21eb0f85569b29a_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_b77015d96164d293a21eb0f85569b29a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_b77015d96164d293a21eb0f85569b29a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b77015d96164d293a21eb0f85569b29a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b77015d96164d293a21eb0f85569b29a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b77015d96164d293a21eb0f85569b29a = L.geoJson(null, {
#                 onEachFeature: geo_json_b77015d96164d293a21eb0f85569b29a_onEachFeature,
#
#                 style: geo_json_b77015d96164d293a21eb0f85569b29a_styler,
#                 pointToLayer: geo_json_b77015d96164d293a21eb0f85569b29a_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b77015d96164d293a21eb0f85569b29a_add (data) {
#             geo_json_b77015d96164d293a21eb0f85569b29a
#                 .addData(data);
#         }
#             geo_json_b77015d96164d293a21eb0f85569b29a_add({&quot;bbox&quot;: [24.721367000363124, 60.14792099956579, 25.159346348813475, 60.280756075130455], &quot;features&quot;: [{&quot;bbox&quot;: [24.84031900081687, 60.16582000019192, 24.84031900081687, 60.16582000019192], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.84031900081687, 60.16582000019192], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;Hanasaarenranta 1&quot;, &quot;Capacity&quot;: 10, &quot;ID&quot;: &quot;501&quot;, &quot;Name&quot;: &quot;Hanasaari&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [24.827466999929044, 60.1715239996662, 24.827466999929044, 60.1715239996662], &quot;geometry&quot;: {&quot;coordinates&quot;: [24.827466999929044, 60.1715239996662], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;Address&quot;: &quot;Keilalahdentie 2&quot;, &quot;Capacity&quot;: 28, &quot;ID&quot;: &quot;50

# %% [markdown]
# % This cell is only needed to produce a figure for display in the hard copy of the book.
# \adjustimage{max size={0.9\linewidth}{0.9\paperheight}, caption={\emph{\textbf{Figure 8.XX}. Interactive map with point data and custom bacground tiles.}}, center, nofloat}{../img/figure_8-xxx.png}
# { \hspace*{\fill} \\}

# %% [markdown]
# _**Figure 8.XXX**. Interactive map with point data and custom bacground tiles._

# %% [markdown]
# ## Choropleth map
#
# It is also possible to plot interactive choropleth maps using `GeoDataFrame.explore()`. Let's create a choropleth map displaying the spatial distribution of city bike stations in the Helsinki metropolitan area. For this, we can read in [postal code data provided by the Helsinki Region Environmental Services Authority](https://www.hsy.fi/en/environmental-information/open-data/avoin-data---sivut/-helsinki-metropolitan-postal-code-areas/) [^hsy_postalcodedata]. Columns `"Posno"`, `"Nimi"`, and `"Kunta"` contain relevant information about the postal code areas and we can rename these columns for clarity.

# %%
polygons_fp = "./../data/PKS_postinumeroalueet_2023_manner_shp.zip"
polygons = gpd.read_file(polygons_fp, columns=["Posno", "Nimi", "Kunta"])

polygons = polygons.rename(
    columns={"Posno": "Postal code", "Nimi": "Name", "Kunta": "Municipality"}
)

polygons.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebbf4254dc9f96078e3970fed132f80c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebbf4254dc9f96078e3970fed132f80c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebbf4254dc9f96078e3970fed132f80c = L.map(
#                 &quot;map_ebbf4254dc9f96078e3970fed132f80c&quot;,
#                 {
#                     center: [60.231844965449, 24.87689941767285],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ebbf4254dc9f96078e3970fed132f80c);
#
#
#
#
#
#             var tile_layer_8488d67babe29c18b6514b081d1aa0f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8488d67babe29c18b6514b081d1aa0f0.addTo(map_ebbf4254dc9f96078e3970fed132f80c);
#
#
#             map_ebbf4254dc9f96078e3970fed132f80c.fitBounds(
#                 [[60.062434433698435, 24.499302263685312], [60.40125549719956, 25.254496571660386]],
#                 {}
#             );
#
#
#         function geo_json_433aa7126e48b909e5f0ed2e541a3b91_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_433aa7126e48b909e5f0ed2e541a3b91_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_433aa7126e48b909e5f0ed2e541a3b91_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_433aa7126e48b909e5f0ed2e541a3b91_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_433aa7126e48b909e5f0ed2e541a3b91_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_433aa7126e48b909e5f0ed2e541a3b91.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_433aa7126e48b909e5f0ed2e541a3b91_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_433aa7126e48b909e5f0ed2e541a3b91 = L.geoJson(null, {
#                 onEachFeature: geo_json_433aa7126e48b909e5f0ed2e541a3b91_onEachFeature,
#
#                 style: geo_json_433aa7126e48b909e5f0ed2e541a3b91_styler,
#                 pointToLayer: geo_json_433aa7126e48b909e5f0ed2e541a3b91_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_433aa7126e48b909e5f0ed2e541a3b91_add (data) {
#             geo_json_433aa7126e48b909e5f0ed2e541a3b91
#                 .addData(data);
#         }
#             geo_json_433aa7126e48b909e5f0ed2e541a3b91_add({&quot;bbox&quot;: [24.499302263685312, 60.062434433698435, 25.254496571660386, 60.40125549719956], &quot;features&quot;: [{&quot;bbox&quot;: [24.942902219373355, 60.14825229137016, 24.96774101162378, 60.16223527118647], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[24.96774101162378, 60.15015626276939], [24.967138957053972, 60.149296013799855], [24.966490641400018, 60.149365510026506], [24.965361169777882, 60.149164581967185], [24.965243433167075, 60.149371202297274], [24.96599185366323, 60.14957168405465], [24.965599287350496, 60.150274316865634], [24.96557485459745, 60.1508712956656], [24.965966563965523, 60.151588949357375], [24.96637948448319, 60.151606646680925], [24.967400712324245, 60.

# %% [markdown]
# % This cell is only needed to produce a figure for display in the hard copy of the book.
# \adjustimage{max size={0.9\linewidth}{0.9\paperheight}, caption={\emph{\textbf{Figure 8.XXXX}. Interactive map with polygon data.}}, center, nofloat}{../img/figure_8-xxxx.png}
# { \hspace*{\fill} \\}

# %% [markdown]
# _**Figure 8.XXXX**. Interactive map with polygon data._

# %% [markdown]
# Let's combine information about city bike stations into the postal code data including the total number of stations and total station capacity per postal code area. Finally, let's calculate the average capacity per city bike station per postal code area to generate information that we can display on our thematic map.

# %%
# Create spatial join
join = gpd.sjoin(polygons, points[["ID", "Capacity", "geometry"]])

# Get station count and total capacity per postal code
bike_count = join.groupby(["Postal code"]).ID.count()
capacity = join.groupby(["Postal code"]).Capacity.sum()

# Join statistics to polygons
polygons = polygons.merge(
    bike_count, left_on="Postal code", right_index=True, how="left"
)
polygons = polygons.merge(capacity, left_on="Postal code", right_index=True, how="left")

polygons = polygons.rename(
    columns={"ID": "Number of stations", "Capacity": "Total capacity"}
)
polygons["Average city bike station capacity"] = (
    polygons["Total capacity"] / polygons["Number of stations"]
)

# %%
polygons.explore(column="Average city bike station capacity")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e47c75acc1c66e707ff1f0000b46c00c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e47c75acc1c66e707ff1f0000b46c00c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e47c75acc1c66e707ff1f0000b46c00c = L.map(
#                 &quot;map_e47c75acc1c66e707ff1f0000b46c00c&quot;,
#                 {
#                     center: [60.231844965449, 24.87689941767285],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_e47c75acc1c66e707ff1f0000b46c00c);
#
#
#
#
#
#             var tile_layer_e8c3601493ef95fe4a8725d151bbe0fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8c3601493ef95fe4a8725d151bbe0fd.addTo(map_e47c75acc1c66e707ff1f0000b46c00c);
#
#
#             map_e47c75acc1c66e707ff1f0000b46c00c.fitBounds(
#                 [[60.062434433698435, 24.499302263685312], [60.40125549719956, 25.254496571660386]],
#                 {}
#             );
#
#
#         function geo_json_68755f19cd2292cd6329e940fcdb44b3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#287c8e&quot;, &quot;fillColor&quot;: &quot;#287c8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;8&quot;: case &quot;12&quot;: case &quot;17&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;30&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;35&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;43&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;49&quot;: case &quot;52&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;57&quot;: case &quot;64&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;69&quot;: case &quot;71&quot;: case &quot;73&quot;: case &quot;75&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;86&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;97&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;122&quot;: case &quot;125&quot;: case &quot;127&quot;: case &quot;131&quot;: case &quot;132&quot;: case &quot;134&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;141&quot;: case &quot;142&quot;: case &quot;147&quot;: case &quot;157&quot;: case &quot;158&quot;: case &quot;159&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;163&quot;: case &quot;167&quot;: case &quot;169&quot;:
#                     return {&quot;color&quot;: null, &quot;fillColor&quot;: null, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;61&quot;:
#                     return {&quot;color&quot;: &quot;#2a788e&quot;, &quot;fillColor&quot;: &quot;#2a788e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#218f8d&quot;, &quot;fillColor&quot;: &quot;#218f8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;98&quot;:
#                     return {&quot;color&quot;: &quot;#1f9e89&quot;, &quot;fillColor&quot;: &quot;#1f9e89&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;23&quot;: case &quot;48&quot;: case &quot;100&quot;: case &quot;123&quot;: case &quot;149&quot;: case &quot;168&quot;: case &quot;

# %% [markdown]
# _**Figure 8.XXXX**. Interactive choropleth map displaying the average city bike station capacity per postal code area._

# %% [markdown]
# Our map displays the average city bike station capacity across all postal code areas in the region. The highest capacity can be observed in downtown Helsinki. Other attributes, such as the total number of stations and total capacity per postal code can be viewed when hovering over the map. The city bike station data covers only the municipality of Helsinki and parts of the neighbouring municipality of Espoo. Those postal code areas without any city bike stations are visualized in gray.

# %% [markdown]
# ## Folium plugins
#
# So far, we have used `folium` via geopandas to create the interactive maps. For further options, we can start using various plugins available from leaflet via [`folium` plugins](https://python-visualization.github.io/folium/plugins.html) [^folium_plugins].
#
#
# First, create a simple interactive map and recap some of the basic settings we already used when plotting interactive maps via `geopandas`.  We will create [a `folium` map instance](https://python-visualization.github.io/folium/modules.html#folium.folium.Map) and define the initial location for the interactive map and add a simple [marker](https://python-visualization.github.io/folium/modules.html?highlight=marker#folium.map.Marker). Furthermore, we can adjusts the initial zoom-level for the map (the higher the number the closer the zoom is) using the `zoom_start` parameter, and display the scalebar using the `control_scale` parameter.

# %%
import folium

# %%
# Create a Map instance
m = folium.Map(location=[60.20, 24.96], zoom_start=12, control_scale=True)

# Add marker
# Run: help(folium.Icon) for more info about icons
folium.Marker(
    location=[60.20426, 24.96179],
    popup="Kumpula Campus",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b350f5d703324323234de0c105f1fd2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b350f5d703324323234de0c105f1fd2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b350f5d703324323234de0c105f1fd2f = L.map(
#                 &quot;map_b350f5d703324323234de0c105f1fd2f&quot;,
#                 {
#                     center: [60.2, 24.96],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#
#
#
#             var tile_layer_e57494c6ce5c551d1d38aa30569f2187 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e57494c6ce5c551d1d38aa30569f2187.addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#             var marker_b655acbb52016a83fa94dcafac7ea49d = L.marker(
#                 [60.20426, 24.96179],
#                 {
# }
#             ).addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#             var icon_608841fa2665f3a9f2af89b2759c643c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_21332b2e62bff98778a5f2cf9ba9b204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e4d975beaeef4aa0531bc198e0f340f = $(`&lt;div id=&quot;html_1e4d975beaeef4aa0531bc198e0f340f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kumpula Campus&lt;/div&gt;`)[0];
#                 popup_21332b2e62bff98778a5f2cf9ba9b204.setContent(html_1e4d975beaeef4aa0531bc198e0f340f);
#
#
#
#         marker_b655acbb52016a83fa94dcafac7ea49d.bindPopup(popup_21332b2e62bff98778a5f2cf9ba9b204)
#         ;
#
#
#
#
#                 marker_b655acbb52016a83fa94dcafac7ea49d.setIcon(icon_608841fa2665f3a9f2af89b2759c643c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To fully understand what happens, we can save the map as a HTML (Hypertext Markup Language) file and inspect how the interactive map is defined in text format.

# %%
outfp = "./../data/base_map.html"
m.save(outfp)

# %% [markdown]
# You should now see a html file in the data directory. You can open the file in a web-browser in order to see the map, or in a text editor in order to see the source definition HTML.

# %% [markdown]
# ### Layer control
#
# We can also allow users to control what contents are displayed on the map by adding add a [`LayerControl`](http://python-visualization.github.io/folium/docs-v0.5.0/modules.html#folium.map.LayerControl) object on our map. It is possible to control, for example, the position of the layer control icon while adding it. Note, that the `LayerControl` object should be added last, after all map layers have been added to ensure that it works correctly.

# %%
# Create a layer control object and add it to our map instance
folium.LayerControl(position="topleft").add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b350f5d703324323234de0c105f1fd2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b350f5d703324323234de0c105f1fd2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b350f5d703324323234de0c105f1fd2f = L.map(
#                 &quot;map_b350f5d703324323234de0c105f1fd2f&quot;,
#                 {
#                     center: [60.2, 24.96],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#
#
#
#             var tile_layer_e57494c6ce5c551d1d38aa30569f2187 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e57494c6ce5c551d1d38aa30569f2187.addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#             var marker_b655acbb52016a83fa94dcafac7ea49d = L.marker(
#                 [60.20426, 24.96179],
#                 {
# }
#             ).addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#             var icon_608841fa2665f3a9f2af89b2759c643c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_21332b2e62bff98778a5f2cf9ba9b204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e4d975beaeef4aa0531bc198e0f340f = $(`&lt;div id=&quot;html_1e4d975beaeef4aa0531bc198e0f340f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kumpula Campus&lt;/div&gt;`)[0];
#                 popup_21332b2e62bff98778a5f2cf9ba9b204.setContent(html_1e4d975beaeef4aa0531bc198e0f340f);
#
#
#
#         marker_b655acbb52016a83fa94dcafac7ea49d.bindPopup(popup_21332b2e62bff98778a5f2cf9ba9b204)
#         ;
#
#
#
#
#                 marker_b655acbb52016a83fa94dcafac7ea49d.setIcon(icon_608841fa2665f3a9f2af89b2759c643c);
#
#
#             tile_layer_e57494c6ce5c551d1d38aa30569f2187.addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#                 marker_b655acbb52016a83fa94dcafac7ea49d.setIcon(icon_608841fa2665f3a9f2af89b2759c643c);
#
#
#             tile_layer_e57494c6ce5c551d1d38aa30569f2187.addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
#                 marker_b655acbb52016a83fa94dcafac7ea49d.setIcon(icon_608841fa2665f3a9f2af89b2759c643c);
#
#
#             var layer_control_b007e5318bfe8511c6227dd0ef7350d3_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e57494c6ce5c551d1d38aa30569f2187,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_b007e5318bfe8511c6227dd0ef7350d3 = L.control.layers(
#                 layer_control_b007e5318bfe8511c6227dd0ef7350d3_layers.base_layers,
#                 layer_control_b007e5318bfe8511c6227dd0ef7350d3_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_b350f5d703324323234de0c105f1fd2f);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Heatmap
#
# The [`HeatMap`](https://python-visualization.github.io/folium/plugins.html#folium.plugins.HeatMap) plugin creates a heatmap layer from input points. Let's visualize a heatmap of the city bike station data based on the original point locations. The `HeatMap` plugin requires a list of point coordinates (latitude, longitude), or a `numpy` array as input. Let's create the required input using our `geopandas` skills.

# %%
points = points.to_crs(4326)

# Get x and y coordinates for each point
points["x"] = points["geometry"].x
points["y"] = points["geometry"].y

# Create a list of coordinate pairs
locations = list(zip(points["y"], points["x"]))

# Comment out the following line to check the result
# print(locations)

# %% [markdown]
# Now that we have a list of point coordinates, we can pass this list onto `folium` `HeatMap` plugin:

# %%
from folium.plugins import HeatMap

# Create a Map instance
m = folium.Map(
    location=[60.25, 24.8], tiles="CartoDB Positron", zoom_start=10, control_scale=True
)

# Add heatmap to map instance
HeatMap(locations).add_to(m)

# Alternative syntax:
# m.add_child(HeatMap(points_array, radius=15))

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a937530c750731febc0a9790dea6484d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a937530c750731febc0a9790dea6484d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a937530c750731febc0a9790dea6484d = L.map(
#                 &quot;map_a937530c750731febc0a9790dea6484d&quot;,
#                 {
#                     center: [60.25, 24.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a937530c750731febc0a9790dea6484d);
#
#
#
#
#
#             var tile_layer_cf1adb9b820425962fbb14326cc1fba6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf1adb9b820425962fbb14326cc1fba6.addTo(map_a937530c750731febc0a9790dea6484d);
#
#
#             var heat_map_f1d3edcdf329ed91736417b22d894081 = L.heatLayer(
#                 [[60.16582000019192, 24.84031900081687], [60.1715239996662, 24.827466999929044], [60.16826599993541, 24.805758000284836], [60.16814300014226, 24.796135999589517], [60.171550999885284, 24.802937999572396], [60.17342399958105, 24.810688000031373], [60.17356700030718, 24.791389999329958], [60.17576900043228, 24.792558999391126], [60.175358000061756, 24.80204899954363], [60.1741439999027, 24.806050999871204], [60.17616799998392, 24.80582500019237], [60.17758799986143, 24.8039420001398], [60.17875000011794, 24.79798399972573], [60.17870200019453, 24.810974000655406], [60.17865499990523, 24.817423000798527], [60.175233000341414, 24.82894999918447], [60.17876200034733, 24.83513200049163], [60.1800270000291, 24.83180400045064], [60.180805999709946, 24.824747000388147], [60.185096000204545, 24.814220000805154], [60.18363000021447, 24.817403000265543], [60.18498699988509, 24.82009899964647], [60.1843120002421, 24.826670999367597], [60.18483000000188, 24.83713300056317], [60.188499000245365, 24.82998500015372], [60.188118000216164, 24.83503299979367], [60.187529000412745, 24.810192999818348], [60.18914300024852, 24.8070829997448], [60.18673100009035, 24.806151999920996], [60.18476499981486, 24.804021999800977], [60.18715000038178, 24.79695899985821], [60.182879999970304, 24.794014000205784], [60.18297600043132, 24.785760000318646], [60.188706000247315, 24.78047800083549], [60.19459899960411, 24.769020999934348], [60.17774899971827, 24.784654000172246], [60.17464999975445, 24.7794280003174], [60.17610699988645, 24.769666999912893], [60.180848000160815, 24.760606000627707], [60.171126999863354, 24.775912999190947], [60.17075799973826, 24.7631839998146], [60.16648099963511, 24.772708000204883], [60.16239599978596, 24.775882000337365], [60.16247700001166, 24.76783099919153], [60.15804800006859, 24.769863999772973], [60.154940999950696, 24.77399300045252], [60.159140499903614, 24.78247700021321], [60.158193999572404, 24.79175400062873], [60.162447100123984, 24.784862800420555], [60.163699999602876, 24.790131999580503], [60.14797399969725, 24.754344000209997], [60.15104100002296, 24.754195999899167], [60.14792099956579, 24.74154599914253], [60.15234300031083, 24.74123399991699], [60.15625799998361, 24.75248900074465], [60.155688999560496, 24.744977999542083], [60.15675500039299, 24.73766400017492], [60.15373700020125, 24.729112000505225], [60.160644999645434, 24.72483499954185], [60.161137999890215, 24.756271999541628], [60.1615879999437, 24.746629999334967], [60.16001499982478, 24.741294000029562], [60.16240299982718, 24.738415999290506], [60.165603000279, 24.732688000583135], [60.16284200001317, 24.721367000363124], [60.16897099957175, 24.724908000310243], [60.17267299972619, 24.726025000089383], [60.174524000405725, 24.729314000293357], [60.174914000111585, 24.738122000520775], [60.16721600036685, 24.73596899954278], [60.171547999920215, 24.73147200008807], [60.168440999587396, 24.743531999412305], [60.1728140000402, 24.74566599977507], [60.174709999654674, 24.75244199922943], [60.18459600009978, 24.74413100065581], [60.18705199968587, 24.742570999715376], [60.20614199974749, 24.84069899978525], [60.203851999957976, 24.82310000033281], [60.2038920002699, 24.80492999993356], [60.21073499969614, 24.82495400065216], [60.21250799973566, 24.819549000035774], [60.21575100017725, 24.82636800011802], [60.216067000062964, 24.819395999655715], [60.216221999842936, 24.821932000003258], [60.21344300024027, 24.811571999222146], [60.214192999907354, 24.805612999426767], [60.21466599961161, 24.80048600051457], [60.21726099988718, 24.80627900002281], [60.21731099969166, 24.812419000513557], [60.2188690003188, 24.81388500061074], [60.22025399980198, 24.81343699

# %% [markdown]
# ### Clustered point map
#
# [`MarkerCluster`](https://python-visualization.github.io/folium/plugins.html?highlight=marker%20cluster#folium.plugins.MarkerCluster)  is another useful `folium` plugin that allows simplifying the displayed information according to the zoom level. When zooming out, the displayed markers are clustered together and more details appear when zooming in.  Let's visualize the address points (locations of transport stations in Helsinki) using this approach. Similar to the `HeatMap`plugin, the `MarkerCluster` plugin requires the input as a list of coordinate tuples, and we can use the same list of point coordinates also here.

# %%
from folium.plugins import MarkerCluster

# %%
# Create a Map instance
m = folium.Map(
    location=[60.25, 24.8], tiles="CartoDB Positron", zoom_start=11, control_scale=True
)

# %%
# Create a folium marker cluster
marker_cluster = MarkerCluster(locations)

# Add marker cluster to map
marker_cluster.add_to(m)

# Show map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0898b26e511664b3f12c408bc13d3e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0898b26e511664b3f12c408bc13d3e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0898b26e511664b3f12c408bc13d3e4 = L.map(
#                 &quot;map_d0898b26e511664b3f12c408bc13d3e4&quot;,
#                 {
#                     center: [60.25, 24.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d0898b26e511664b3f12c408bc13d3e4);
#
#
#
#
#
#             var tile_layer_bcba72ecb25b26d3849f94104e177d7b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcba72ecb25b26d3849f94104e177d7b.addTo(map_d0898b26e511664b3f12c408bc13d3e4);
#
#
#             var marker_cluster_505ba87c85525becf7f3ebc5b0b796c0 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_2fdda6712b076ff2ec925491eb394d68 = L.marker(
#                 [60.16582000019192, 24.84031900081687],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_9d7079c64c78325c9114074093a12f47 = L.marker(
#                 [60.1715239996662, 24.827466999929044],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_71dbcb2e21d17ab1f4f11e01d11a1289 = L.marker(
#                 [60.16826599993541, 24.805758000284836],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_c3d234276ac1343c9dd7e84d452edeac = L.marker(
#                 [60.16814300014226, 24.796135999589517],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_0c3342405242ded09873f2c64172b6bc = L.marker(
#                 [60.171550999885284, 24.802937999572396],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_5cde424143f08288de93c55904a0a972 = L.marker(
#                 [60.17342399958105, 24.810688000031373],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_73cda0a17c0aed8d082e94b708c6b840 = L.marker(
#                 [60.17356700030718, 24.791389999329958],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_6c3c05846f62ecc8820c1ca39df7fe16 = L.marker(
#                 [60.17576900043228, 24.792558999391126],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_c040332f5e4cc55f2d87cdfb82bdee6a = L.marker(
#                 [60.175358000061756, 24.80204899954363],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_4f63fff0bd303aabb9da81d257ffce87 = L.marker(
#                 [60.1741439999027, 24.806050999871204],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_ad45ebd239a11f1ee6714a9d9db058b4 = L.marker(
#                 [60.17616799998392, 24.80582500019237],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_9fa2c8bfe1ece2b40ded8a054e7b7797 = L.marker(
#                 [60.17758799986143, 24.8039420001398],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_73de9cca59457bf537c069cde30418b0 = L.marker(
#                 [60.17875000011794, 24.79798399972573],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_bb0a61d3087fcb62385e4bf18bf397c3 = L.marker(
#                 [60.17870200019453, 24.810974000655406],
#                 {
# }
#             ).addTo(marker_cluster_505ba87c85525becf7f3ebc5b0b796c0);
#
#
#             var marker_a6dc832f1ae8b7647b946eaaf0e71fda = L.marker(
#                 [60.17865499990523, 24.817423000798527],
#                 {
# }

# %% [markdown]
# ## Footnotes
#
# [^folium]: <https://python-visualization.github.io/folium/>
# [^leaflet]: <http://leafletjs.com/>
# [^hsl_citybikedata]: <https://www.avoindata.fi/data/en_GB/dataset/hsl-n-kaupunkipyoraasemat>
# [^hsy_postalcodedata]: <https://www.hsy.fi/en/environmental-information/open-data/avoin-data---sivut/-helsinki-metropolitan-postal-code-areas/>
# [^folium_api]: <https://python-visualization.github.io/folium/latest/reference.html>
# [^xyzservices]: <https://xyzservices.readthedocs.io/en/stable/>
# [^leaflet_providers]: <https://leaflet-extras.github.io/leaflet-providers/preview/>
# [^folium_plugins]: <https://python-visualization.github.io/folium/plugins.html>
